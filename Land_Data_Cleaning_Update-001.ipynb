# %% [markdown]
# # Environment conda3--python3
# ## Coding UTF-8
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import missingno as msno

# show library versions for documentation reference
import sys
print("Python: {}".format(sys.version))
print("pandas: {}".format(pd.__version__))
print("numpy: {}".format(np.__version__))
print("seaborn: {}".format(sns.__version__))
print("missingno: {}".format(msno.__version__))
# Out:
# Python: 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# pandas: 1.0.3
# numpy: 1.18.1
# seaborn: 0.10.1
# missingno: 0.4.2

# %% [markdown]
# ### Load Land Dataset

# %%
df_land_new = pd.read_excel(r'C:\Users\OS\Desktop\Model Improvement Dataset\Land-New Dataset 08-2020.xlsx')
df_land_current = pd.read_excel(r'C:\Users\OS\Desktop\Model Improvement Dataset\Land-Current Dataset 09-2020.xlsx')

# %% [markdown]
# ### Show Data --Land_Dataset

# %%
# show example data from loaded file
df_land_new
# Out:
#    ID_Lands                                          ColorType  \
# 0     l2407      พื้นที่สีเขียว – ที่ดินประเภทชนบทและเกษตรกรรม
# 1     l6063  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 2     l5858  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 3     l9837  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 4     l0740  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 5     l6501  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 6     l7962  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 7     l3274  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 8     l6249  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 9     l2486  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 10    l8372  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 11    l4997  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 12    l4768  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 13    l2525  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 14    l1132  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 15    l7913  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 16    l0964  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 17    l5646  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 18    l6684  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 19    l0536  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 20    l5653              พื้นที่สีแดง – ที่ดินประเภทพาณิชยกรรม
# 21    l6290  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
#
#                                            AnnounceTH CodeDeed TypeCode  \
# 0   ที่หลายเนินสวยมากหายากเป็นส่วนตัว ขายที่ดินเขา...    l2407
# 1                             ที่ดิน แม่ข้าวต้ม แปลงC    l6063
# 2                            ที่ดิน แม่ข้าวต้ม แปลงB8    l5858
# 3                            ที่ดิน แม่ข้าวต้ม แปลงB5    l9837
# 4                            ที่ดิน แม่ข้าวต้ม แปลงB4    l0740
# 5                            ที่ดิน แม่ข้าวต้ม แปลงB7    l6501
# 6                            ที่ดิน แม่ข้าวต้ม แปลงB6    l7962
# 7                            ที่ดิน แม่ข้าวต้ม แปลงB3    l3274
# 8                            ที่ดิน แม่ข้าวต้ม แปลงB2    l6249
# 9                            ที่ดิน แม่ข้าวต้ม แปลงB1    l2486
# 10                           ที่ดิน แม่ข้าวต้ม แปลงA9    l8372
# 11                           ที่ดิน แม่ข้าวต้ม แปลงA8    l4997
# 12                           ที่ดิน แม่ข้าวต้ม แปลงA7    l4768
# 13                           ที่ดิน แม่ข้าวต้ม แปลงA5    l2525
# 14                           ที่ดิน แม่ข้าวต้ม แปลงA6    l1132
# 15                           ที่ดิน แม่ข้าวต้ม แปลงA4    l7913
# 16                           ที่ดิน แม่ข้าวต้ม แปลงA3    l0964
# 17                           ที่ดิน แม่ข้าวต้ม แปลงA2    l5646
# 18                           ที่ดิน แม่ข้าวต้ม แปลงA1    l6684
# 19                                    test model land
# 20                                              55555    l5653
# 21                                          ที่ดินสวย    l6290
#
#    CodeProperty  SellPrice  Costestimate  CostestimateB  MarketPrice  ...  \
# 0        564554  225000000     226000000      225000000    226100000  ...
# 1                  6050000             0              0            0  ...
# 2                  5600000             0              0            0  ...
# 3                  5600000             0              0            0  ...
# 4                  2800000             0              0            0  ...
# 5                  2100000             0              0            0  ...
# 6                   750000             0              0            0  ...
# 7                   750000             0              0            0  ...
# 8                   750000             0              0            0  ...
# 9                   750000             0              0            0  ...
# 10                 2800000             0              0            0  ...
# 11                 2800000             0              0            0  ...
# 12                 2800000             0              0            0  ...
# 13                  600000             0              0            0  ...
# 14                 2800000             0              0            0  ...
# 15                  600000             0              0            0  ...
# 16                  600000             0              0            0  ...
# 17                  600000             0              0            0  ...
# 18                  600000             0              0            0  ...
# 19      2000000    2000000       2000000        2000000      3000000  ...
# 20          555  555555555       5555555         555555        55555  ...
# 21         2222    3000000       2000000        2300000      2000000  ...
#
#     Mainroad  Insoi  Letc  WxD LandAge   PPStatus  \
# 0          1      0                7.0  ยังไม่ขาย
# 1          0      0        NaN     NaN  ยังไม่ขาย
# 2          0      0        NaN     NaN  ยังไม่ขาย
# 3          0      0        NaN     NaN  ยังไม่ขาย
# 4          0      0        NaN     NaN  ยังไม่ขาย
# 5          0      0        NaN     NaN  ยังไม่ขาย
# 6          0      0        NaN     NaN  ยังไม่ขาย
# 7          0      0        NaN     NaN  ยังไม่ขาย
# 8          0      0        NaN     NaN  ยังไม่ขาย
# 9          0      0        NaN     NaN  ยังไม่ขาย
# 10         0      0        NaN     NaN  ยังไม่ขาย
# 11         0      0        NaN     NaN  ยังไม่ขาย
# 12         0      0        NaN     NaN  ยังไม่ขาย
# 13         0      0        NaN     NaN  ยังไม่ขาย
# 14         0      0        NaN     NaN  ยังไม่ขาย
# 15         0      0        NaN     NaN  ยังไม่ขาย
# 16         0      0        NaN     NaN  ยังไม่ขาย
# 17         0      0        NaN     NaN  ยังไม่ขาย
# 18         0      0        NaN     NaN  ยังไม่ขาย
# 19         0      0     0    0     NaN
# 20         0      0        NaN     5.0  ยังไม่ขาย
# 21         0      1        NaN     4.0  ยังไม่ขาย
#
#                                               ImageEX Owner  \
# 0   https://landvist.xyz/images/img_1590717766856.jpg    58
# 1   https://landvist.xyz/images/NewImg/img_1595847...    79
# 2   https://landvist.xyz/images/NewImg/img_1595847...    79
# 3       https://landvist.xyz/images/Defult/Defult.png    79
# 4   https://landvist.xyz/images/NewImg/img_1595845...    79
# 5   https://landvist.xyz/images/NewImg/img_1595847...    79
# 6   https://landvist.xyz/images/NewImg/img_1595847...    79
# 7   https://landvist.xyz/images/NewImg/img_1595846...    79
# 8   https://landvist.xyz/images/NewImg/img_1595847...    79
# 9   https://landvist.xyz/images/NewImg/img_1595846...    79
# 10  https://landvist.xyz/images/NewImg/img_1595847...    79
# 11  https://landvist.xyz/images/NewImg/img_1595846...    79
# 12  https://landvist.xyz/images/NewImg/img_1595846...    79
# 13  https://landvist.xyz/images/NewImg/img_1595846...    79
# 14  https://landvist.xyz/images/NewImg/img_1595846...    79
# 15  https://landvist.xyz/images/NewImg/img_1595847...    79
# 16  https://landvist.xyz/images/NewImg/img_1595846...    79
# 17  https://landvist.xyz/images/NewImg/img_1595847...    79
# 18  https://landvist.xyz/images/NewImg/img_1595847...    79
# 19  https://www.landvist.xyz/images/Defult/Defult.png    46
# 20  https://landvist.xyz/images/NewImg/img_1591202...    27
# 21      https://landvist.xyz/images/Defult/Defult.png    65
#
#                Created    UserType
# 0  2020-05-29 00:00:00  Short-Term
# 1  2020-07-22 22:47:31  Short-Term
# 2  2020-07-22 22:45:07  Short-Term
# 3  2020-07-22 22:42:50  Short-Term
# 4  2020-07-22 22:40:58  Short-Term
# 5  2020-07-22 22:27:16  Short-Term
# 6  2020-07-22 22:26:03  Short-Term
# 7  2020-07-22 22:22:48  Short-Term
# 8  2020-07-22 22:20:41  Short-Term
# 9  2020-07-22 22:18:40  Short-Term
# 10 2020-07-22 22:15:03  Short-Term
# 11 2020-07-22 22:13:19  Short-Term
# 12 2020-07-22 22:11:15  Short-Term
# 13 2020-07-22 22:08:04  Short-Term
# 14 2020-07-22 22:07:10  Short-Term
# 15 2020-07-22 21:57:01  Short-Term
# 16 2020-07-22 21:55:05  Short-Term
# 17 2020-07-22 21:43:54  Short-Term
# 18 2020-07-22 21:40:55  Short-Term
# 19 2020-06-08 20:51:01  Short-Term
# 20 2020-06-03 23:32:43  Short-Term
# 21 2020-06-03 22:16:55  Short-Term
#
# [22 rows x 52 columns]

# %%
df_land_current
# Out:
#     ID_Lands                                          ColorType  \
# 0      l0075  พื้นที่สีขาวมีกรอบและเส้นทะแยงสีเขียว – ที่ดิน...
# 1      l0316  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 2      l0401  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 3      l0437      พื้นที่สีเขียว – ที่ดินประเภทชนบทและเกษตรกรรม
# 4      l0438  พื้นที่สีน้ำตาล – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# ..       ...                                                ...
# 150    l9800  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 151    l9837  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 152    l9842  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 153    l9935  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 154    l9979  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
#
#                                             AnnounceTH CodeDeed TypeCode  \
# 0        ขายที่ดินแปลงสวย 1 ไร่ 3 งาน อ. แม่ริม จ. เชี    l0075
# 1                                             Training    l0316
# 2                               ที่สวย ทำเลงาม บางเสร่    l0401
# 3        ขายที่ดินเปล่า เนื้อที่ 100 ไร่ ต. ดงมหาวัน อ    l0437
# 4                         ขายที่ดินบางซ่อน เขตบางซื่อ     l0438
# ..                                                 ...      ...      ...
# 150                                           Training    l9800
# 151                           ที่ดิน แม่ข้าวต้ม แปลงB5    l9837
# 152  ขายที่ดิน 34 ไร่ 3 งาน 66 ตรว (นส.3ก) เชียงของ...    l9842
# 153  ขายที่ดิน เนื้อที่350 ตรว 4แปลง ที่ดินตั้งอยู่...    l9935
# 154                          ขายที่ดินทำเลดี บุรีรัมย์    l9979
#
#     CodeProperty  SellPrice  Costestimate  CostestimateB  MarketPrice  ...  \
# 0            562    7000000       8000000        8000000      7500000  ...
# 1                   3600000       3200000        3000000      3400000  ...
# 2            621    8720000       8600000        8500000      8600000  ...
# 3        6402761   45000000      44200000       43500000     46000000  ...
# 4            237   26400000      25200000       25400000     26000000  ...
# ..           ...        ...           ...            ...          ...  ...
# 150                30000000      29000000       28000000     29500000  ...
# 151                 5600000             0              0            0  ...
# 152                 6983000             0              0            0  ...
# 153                 4900000             0              0            0  ...
# 154          502   16200000      16000000       16000000     15000000  ...
#
#      Mainroad  Insoi Letc  WxD LandAge   PPStatus  \
# 0           1      0       NaN       5  ยังไม่ขาย
# 1           1      0       NaN     NaN  ยังไม่ขาย
# 2           0      1       NaN       3  ยังไม่ขาย
# 3           1      0       NaN       3
# 4           0      1       NaN       3  ยังไม่ขาย
# ..        ...    ...  ...  ...     ...        ...
# 150         0      0       NaN       1  ยังไม่ขาย
# 151         0      0       NaN     NaN  ยังไม่ขาย
# 152         1      0       NaN       0  ยังไม่ขาย
# 153         0      1       NaN     NaN  ยังไม่ขาย
# 154         1      0       NaN       5  ยังไม่ขาย
#
#                                                ImageEX Owner  \
# 0    https://landvist.xyz/images/img_1589049746930.jpg    27
# 1        https://landvist.xyz/images/Defult/Defult.png    30
# 2        https://landvist.xyz/images/Defult/Defult.png    27
# 3     https://landvist.xyz/images/mg_1569590149875.jpg    27
# 4    https://landvist.xyz/images/NewImg/img_1591201...    27
# ..                                                 ...   ...
# 150      https://landvist.xyz/images/Defult/Defult.png    63
# 151      https://landvist.xyz/images/Defult/Defult.png    79
# 152      https://landvist.xyz/images/Defult/Defult.png    79
# 153      https://landvist.xyz/images/Defult/Defult.png    79
# 154      https://landvist.xyz/images/Defult/Defult.png    59
#
#                  Created    UserType
# 0    1477-05-09 00:07:21   Long-Term
# 1    1476-11-17 08:18:33  Short-Term
# 2    1476-11-18 04:27:40   Long-Term
# 3    1476-09-27 10:45:32   Long-Term
# 4    1476-11-21 16:00:32   Long-Term
# ..                   ...         ...
# 150  1476-11-17 08:15:29   Long-Term
# 151  1477-07-22 01:17:10  Short-Term
# 152  1457-01-01 17:00:00  Short-Term
# 153                  NaN  Short-Term
# 154  1476-11-22 06:38:28  Short-Term
#
# [155 rows x 52 columns]

# %% [markdown]
# #### Visualisatuion assisting Analysis of Data

# %%
#frequency of label in UserType from new Dataset
df_land_new['UserType'].value_counts()
# Out:
# Short-Term    22
# Name: UserType, dtype: int64

# %%
#frequency of label in UserType from old Dataset
fr_current_df = df_land_current['UserType'].value_counts()
fr_current_df
# Out:
# Long-Term     79
# Short-Term    76
# Name: UserType, dtype: int64

# %%
#plotting categorical variables for visualisation
fr_current_df.plot(kind='bar')

# %%
#The next single-line code will visualize the location of missing values.
sns.heatmap(df_land_current.isnull(), cbar=False)
"""We need to know if the occurrence of missing values are sparsely located or located as a big chunk. This heatmap visualization immediately tells us such tendency. Also, if more than 2 columns have correlation in missing value locations, such correlation will be visualized."""
# Out:
# 'We need to know if the occurrence of missing values are sparsely located or located as a big chunk. This heatmap visualization immediately tells us such tendency. Also, if more than 2 columns have correlation in missing value locations, such correlation will be visualized.'

# %%
# Visualize missing values as a Matrix
msno.matrix(df_land_current, labels=True)
"""In addition to the heatmap, there is a bar on the right side of this diagram. This is a line plot for each row's data completeness.Also, missingno.heatmap visualizes the correlation matrix about the locations of missing values in columns."""
# Out:
# "In addition to the heatmap, there is a bar on the right side of this diagram. This is a line plot for each row's data completeness.Also, missingno.heatmap visualizes the correlation matrix about the locations of missing values in columns."

# %%
# Visualiz the missing values as a Bar Chart
msno.bar(df_land_current, labels=True, sort="ascending")
"""A simple representation of nullity by column"""
# Out:
# 'A simple representation of nullity by column'

# %%
# Visualize the correlation between the number of  missing values in different columns as a Heatmap
msno.heatmap(df_land_current)
"""The bar chart of the number of missing values in each column and the dendrogram generated from the correlation of missing value locations. The missingno correlation heatmap measures nullity correlation: how strongly the presence or absence of one variable affects the presence of another."""
# Out:
# 'The bar chart of the number of missing values in each column and the dendrogram generated from the correlation of missing value locations. The missingno correlation heatmap measures nullity correlation: how strongly the presence or absence of one variable affects the presence of another.'

# %%
# Nullity correlation ranges from -1 (if one variable appears the other definitely does not) to 0 
#(variables appearing or not appearing have no effect on one another) to 1 
#(if one variable appears the other definitely also does).

# Entries marked <1 or >-1 are have a correlation that is close to being exactingly negative or positive, 
#but is still not quite perfectly so. This points to a small number of records in the dataset which are erroneous. 
#For example, in this dataset the correlation between WxD and ContactSo 3 is -0.9, indicating that, 
#contrary to our expectation, there are a few records which have one or the other, but not both. 
#These cases will require special attention.

# The heatmap works great for picking out data completeness relationships between variable pairs, 
#but its explanatory power is limited when it comes to larger relationships and it has no particular support 
#for extremely large datasets.

# %% [markdown]
# #### Deal with missing Values

# %%
# Confirm the number of missing values in each column.
df_land_current.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 52 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Lands          155 non-null    object
#  1   ColorType         155 non-null    object
#  2   AnnounceTH        155 non-null    object
#  3   CodeDeed          155 non-null    object
#  4   TypeCode          155 non-null    object
#  5   CodeProperty      155 non-null    object
#  6   SellPrice         155 non-null    int64
#  7   Costestimate      155 non-null    int64
#  8   CostestimateB     155 non-null    int64
#  9   MarketPrice       155 non-null    int64
#  10  PriceWA           155 non-null    float64
#  11  LandR             154 non-null    float64
#  12  LandG             155 non-null    object
#  13  LandWA            153 non-null    float64
#  14  Land              155 non-null    object
#  15  Deed              152 non-null    object
#  16  RoadType          154 non-null    object
#  17  RoadWide          155 non-null    object
#  18  GroundLevel       153 non-null    object
#  19  GroundValue       147 non-null    float64
#  20  MoreDetails       153 non-null    object
#  21  Latitude          143 non-null    float64
#  22  Longitude         143 non-null    float64
#  23  AsseStatus        155 non-null    object
#  24  ObservationPoint  155 non-null    object
#  25  Location          155 non-null    object
#  26  LProvince         154 non-null    object
#  27  LAmphur           155 non-null    object
#  28  LDistrict         155 non-null    object
#  29  LZipCode          155 non-null    object
#  30  ContactUo         147 non-null    float64
#  31  ContactSo         113 non-null    object
#  32  ContactUt         147 non-null    object
#  33  ContactSt         155 non-null    object
#  34  ContactU          147 non-null    object
#  35  ContactS          155 non-null    object
#  36  Place             155 non-null    object
#  37  Blind             155 non-null    int64
#  38  Neareducation     155 non-null    int64
#  39  Cenmarket         155 non-null    int64
#  40  Market            155 non-null    int64
#  41  River             155 non-null    int64
#  42  Mainroad          155 non-null    int64
#  43  Insoi             155 non-null    int64
#  44  Letc              155 non-null    object
#  45  WxD               46 non-null     object
#  46  LandAge           126 non-null    object
#  47  PPStatus          155 non-null    object
#  48  ImageEX           155 non-null    object
#  49  Owner             155 non-null    int64
#  50  Created           151 non-null    object
#  51  UserType          155 non-null    object
# dtypes: float64(7), int64(12), object(33)
# memory usage: 63.1+ KB

# %%
# Checking for missing values in each column
df_land_current.isnull().sum()
# Out:
# ID_Lands              0
# ColorType             0
# AnnounceTH            0
# CodeDeed              0
# TypeCode              0
# CodeProperty          0
# SellPrice             0
# Costestimate          0
# CostestimateB         0
# MarketPrice           0
# PriceWA               0
# LandR                 1
# LandG                 0
# LandWA                2
# Land                  0
# Deed                  3
# RoadType              1
# RoadWide              0
# GroundLevel           2
# GroundValue           8
# MoreDetails           2
# Latitude             12
# Longitude            12
# AsseStatus            0
# ObservationPoint      0
# Location              0
# LProvince             1
# LAmphur               0
# LDistrict             0
# LZipCode              0
# ContactUo             8
# ContactSo            42
# ContactUt             8
# ContactSt             0
# ContactU              8
# ContactS              0
# Place                 0
# Blind                 0
# Neareducation         0
# Cenmarket             0
# Market                0
# River                 0
# Mainroad              0
# Insoi                 0
# Letc                  0
# WxD                 109
# LandAge              29
# PPStatus              0
# ImageEX               0
# Owner                 0
# Created               4
# UserType              0
# dtype: int64

# %%
# Replace RoadType index that contain missing values wth NaN, in order to be able to change string to numeric
# In this case 1 row was replaced in RoadType column.
df_land_current = df_land_current.replace(np.nan).dropna(subset=['RoadType'])
df_land_current
# Out:
#     ID_Lands                                          ColorType  \
# 0      l0075  พื้นที่สีขาวมีกรอบและเส้นทะแยงสีเขียว – ที่ดิน...
# 1      l0316  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 2      l0401  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 3      l0437      พื้นที่สีเขียว – ที่ดินประเภทชนบทและเกษตรกรรม
# 4      l0438  พื้นที่สีน้ำตาล – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# ..       ...                                                ...
# 150    l9800  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 151    l9837  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 152    l9842  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 153    l9935  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 154    l9979  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
#
#                                             AnnounceTH CodeDeed TypeCode  \
# 0        ขายที่ดินแปลงสวย 1 ไร่ 3 งาน อ. แม่ริม จ. เชี    l0075
# 1                                             Training    l0316
# 2                               ที่สวย ทำเลงาม บางเสร่    l0401
# 3        ขายที่ดินเปล่า เนื้อที่ 100 ไร่ ต. ดงมหาวัน อ    l0437
# 4                         ขายที่ดินบางซ่อน เขตบางซื่อ     l0438
# ..                                                 ...      ...      ...
# 150                                           Training    l9800
# 151                           ที่ดิน แม่ข้าวต้ม แปลงB5    l9837
# 152  ขายที่ดิน 34 ไร่ 3 งาน 66 ตรว (นส.3ก) เชียงของ...    l9842
# 153  ขายที่ดิน เนื้อที่350 ตรว 4แปลง ที่ดินตั้งอยู่...    l9935
# 154                          ขายที่ดินทำเลดี บุรีรัมย์    l9979
#
#     CodeProperty  SellPrice  Costestimate  CostestimateB  MarketPrice  ...  \
# 0            562    7000000       8000000        8000000      7500000  ...
# 1                   3600000       3200000        3000000      3400000  ...
# 2            621    8720000       8600000        8500000      8600000  ...
# 3        6402761   45000000      44200000       43500000     46000000  ...
# 4            237   26400000      25200000       25400000     26000000  ...
# ..           ...        ...           ...            ...          ...  ...
# 150                30000000      29000000       28000000     29500000  ...
# 151                 5600000             0              0            0  ...
# 152                 6983000             0              0            0  ...
# 153                 4900000             0              0            0  ...
# 154          502   16200000      16000000       16000000     15000000  ...
#
#      Mainroad  Insoi Letc  WxD LandAge   PPStatus  \
# 0           1      0       NaN       5  ยังไม่ขาย
# 1           1      0       NaN       5  ยังไม่ขาย
# 2           0      1       NaN       3  ยังไม่ขาย
# 3           1      0       NaN       3
# 4           0      1       NaN       3  ยังไม่ขาย
# ..        ...    ...  ...  ...     ...        ...
# 150         0      0                 1  ยังไม่ขาย
# 151         0      0                 1  ยังไม่ขาย
# 152         1      0                 0  ยังไม่ขาย
# 153         0      1                 0  ยังไม่ขาย
# 154         1      0                 5  ยังไม่ขาย
#
#                                                ImageEX Owner  \
# 0    https://landvist.xyz/images/img_1589049746930.jpg    27
# 1        https://landvist.xyz/images/Defult/Defult.png    30
# 2        https://landvist.xyz/images/Defult/Defult.png    27
# 3     https://landvist.xyz/images/mg_1569590149875.jpg    27
# 4    https://landvist.xyz/images/NewImg/img_1591201...    27
# ..                                                 ...   ...
# 150      https://landvist.xyz/images/Defult/Defult.png    63
# 151      https://landvist.xyz/images/Defult/Defult.png    79
# 152      https://landvist.xyz/images/Defult/Defult.png    79
# 153      https://landvist.xyz/images/Defult/Defult.png    79
# 154      https://landvist.xyz/images/Defult/Defult.png    59
#
#                  Created    UserType
# 0    1477-05-09 00:07:21   Long-Term
# 1    1476-11-17 08:18:33  Short-Term
# 2    1476-11-18 04:27:40   Long-Term
# 3    1476-09-27 10:45:32   Long-Term
# 4    1476-11-21 16:00:32   Long-Term
# ..                   ...         ...
# 150  1476-11-17 08:15:29   Long-Term
# 151  1477-07-22 01:17:10  Short-Term
# 152  1457-01-01 17:00:00  Short-Term
# 153  1457-01-01 17:00:00  Short-Term
# 154  1476-11-22 06:38:28  Short-Term
#
# [155 rows x 52 columns]

# %%
# Check if the missing values were replaced.
df_land_current.isnull().sum()
# Out:
# ID_Lands            0
# ColorType           0
# AnnounceTH          0
# CodeDeed            0
# TypeCode            0
# CodeProperty        0
# SellPrice           0
# Costestimate        0
# CostestimateB       0
# MarketPrice         0
# PriceWA             0
# LandR               0
# LandG               0
# LandWA              0
# Land                0
# Deed                0
# RoadType            0
# RoadWide            0
# GroundLevel         0
# GroundValue         0
# MoreDetails         0
# Latitude            0
# Longitude           0
# AsseStatus          0
# ObservationPoint    0
# Location            0
# LProvince           0
# LAmphur             0
# LDistrict           0
# LZipCode            0
# ContactUo           0
# ContactSo           0
# ContactUt           0
# ContactSt           0
# ContactU            0
# ContactS            0
# Place               0
# Blind               0
# Neareducation       0
# Cenmarket           0
# Market              0
# River               0
# Mainroad            0
# Insoi               0
# Letc                0
# WxD                 8
# LandAge             0
# PPStatus            0
# ImageEX             0
# Owner               0
# Created             0
# UserType            0
# dtype: int64

# %% [markdown]
# #### Change String to Numeric Value

# %%
from sklearn.preprocessing import LabelEncoder

# make a copy of the datframe
df_land_updated = df_land_current.copy(deep=True)

# encoding string values into numeric values
le_colorTy = LabelEncoder()
le_asseSt = LabelEncoder()
le_userTy = LabelEncoder()
le_roadTy = LabelEncoder()
le_groundLev = LabelEncoder()

df_land_updated
# Out:
#     ID_Lands                                          ColorType  \
# 0      l0075  พื้นที่สีขาวมีกรอบและเส้นทะแยงสีเขียว – ที่ดิน...
# 1      l0316  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 2      l0401  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 3      l0437      พื้นที่สีเขียว – ที่ดินประเภทชนบทและเกษตรกรรม
# 4      l0438  พื้นที่สีน้ำตาล – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# ..       ...                                                ...
# 150    l9800  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 151    l9837  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 152    l9842  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 153    l9935  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 154    l9979  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
#
#                                             AnnounceTH CodeDeed TypeCode  \
# 0        ขายที่ดินแปลงสวย 1 ไร่ 3 งาน อ. แม่ริม จ. เชี    l0075
# 1                                             Training    l0316
# 2                               ที่สวย ทำเลงาม บางเสร่    l0401
# 3        ขายที่ดินเปล่า เนื้อที่ 100 ไร่ ต. ดงมหาวัน อ    l0437
# 4                         ขายที่ดินบางซ่อน เขตบางซื่อ     l0438
# ..                                                 ...      ...      ...
# 150                                           Training    l9800
# 151                           ที่ดิน แม่ข้าวต้ม แปลงB5    l9837
# 152  ขายที่ดิน 34 ไร่ 3 งาน 66 ตรว (นส.3ก) เชียงของ...    l9842
# 153  ขายที่ดิน เนื้อที่350 ตรว 4แปลง ที่ดินตั้งอยู่...    l9935
# 154                          ขายที่ดินทำเลดี บุรีรัมย์    l9979
#
#     CodeProperty  SellPrice  Costestimate  CostestimateB  MarketPrice  ...  \
# 0            562    7000000       8000000        8000000      7500000  ...
# 1                   3600000       3200000        3000000      3400000  ...
# 2            621    8720000       8600000        8500000      8600000  ...
# 3        6402761   45000000      44200000       43500000     46000000  ...
# 4            237   26400000      25200000       25400000     26000000  ...
# ..           ...        ...           ...            ...          ...  ...
# 150                30000000      29000000       28000000     29500000  ...
# 151                 5600000             0              0            0  ...
# 152                 6983000             0              0            0  ...
# 153                 4900000             0              0            0  ...
# 154          502   16200000      16000000       16000000     15000000  ...
#
#      Mainroad  Insoi Letc  WxD LandAge   PPStatus  \
# 0           1      0       NaN       5  ยังไม่ขาย
# 1           1      0       NaN       5  ยังไม่ขาย
# 2           0      1       NaN       3  ยังไม่ขาย
# 3           1      0       NaN       3
# 4           0      1       NaN       3  ยังไม่ขาย
# ..        ...    ...  ...  ...     ...        ...
# 150         0      0                 1  ยังไม่ขาย
# 151         0      0                 1  ยังไม่ขาย
# 152         1      0                 0  ยังไม่ขาย
# 153         0      1                 0  ยังไม่ขาย
# 154         1      0                 5  ยังไม่ขาย
#
#                                                ImageEX Owner  \
# 0    https://landvist.xyz/images/img_1589049746930.jpg    27
# 1        https://landvist.xyz/images/Defult/Defult.png    30
# 2        https://landvist.xyz/images/Defult/Defult.png    27
# 3     https://landvist.xyz/images/mg_1569590149875.jpg    27
# 4    https://landvist.xyz/images/NewImg/img_1591201...    27
# ..                                                 ...   ...
# 150      https://landvist.xyz/images/Defult/Defult.png    63
# 151      https://landvist.xyz/images/Defult/Defult.png    79
# 152      https://landvist.xyz/images/Defult/Defult.png    79
# 153      https://landvist.xyz/images/Defult/Defult.png    79
# 154      https://landvist.xyz/images/Defult/Defult.png    59
#
#                  Created    UserType
# 0    1477-05-09 00:07:21   Long-Term
# 1    1476-11-17 08:18:33  Short-Term
# 2    1476-11-18 04:27:40   Long-Term
# 3    1476-09-27 10:45:32   Long-Term
# 4    1476-11-21 16:00:32   Long-Term
# ..                   ...         ...
# 150  1476-11-17 08:15:29   Long-Term
# 151  1477-07-22 01:17:10  Short-Term
# 152  1457-01-01 17:00:00  Short-Term
# 153  1457-01-01 17:00:00  Short-Term
# 154  1476-11-22 06:38:28  Short-Term
#
# [155 rows x 52 columns]

# %%
# create new columns containing numeric code of former column
df_land_current['ColorType_n'] = le_colorTy.fit_transform(df_land_current['ColorType'])
df_land_current['AsseStatus_n'] = le_asseSt.fit_transform(df_land_current['AsseStatus'])
df_land_current['UserType_n'] = le_userTy.fit_transform(df_land_current['UserType'])
df_land_current['RoadType_n'] = le_roadTy.fit_transform(df_land_current['RoadType'])
df_land_current['GroundLevel_n'] = le_groundLev.fit_transform(df_land_current['GroundLevel'])
df_land_current
# Out:
#     ID_Lands                                          ColorType  \
# 0      l0075  พื้นที่สีขาวมีกรอบและเส้นทะแยงสีเขียว – ที่ดิน...
# 1      l0316  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 2      l0401  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 3      l0437      พื้นที่สีเขียว – ที่ดินประเภทชนบทและเกษตรกรรม
# 4      l0438  พื้นที่สีน้ำตาล – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# ..       ...                                                ...
# 150    l9800  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
# 151    l9837  พื้นที่สีส้ม – ที่ดินประเภทที่อยู่อาศัยหนาแน่น...
# 152    l9842  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 153    l9935  พื้นที่สีเหลือง – ที่ดินประเภทที่อยู่อาศัยหนาแ...
# 154    l9979  พื้นที่สีม่วง – ที่ดินประเภทอุตสาหกรรมและคลังส...
#
#                                             AnnounceTH CodeDeed TypeCode  \
# 0        ขายที่ดินแปลงสวย 1 ไร่ 3 งาน อ. แม่ริม จ. เชี    l0075
# 1                                             Training    l0316
# 2                               ที่สวย ทำเลงาม บางเสร่    l0401
# 3        ขายที่ดินเปล่า เนื้อที่ 100 ไร่ ต. ดงมหาวัน อ    l0437
# 4                         ขายที่ดินบางซ่อน เขตบางซื่อ     l0438
# ..                                                 ...      ...      ...
# 150                                           Training    l9800
# 151                           ที่ดิน แม่ข้าวต้ม แปลงB5    l9837
# 152  ขายที่ดิน 34 ไร่ 3 งาน 66 ตรว (นส.3ก) เชียงของ...    l9842
# 153  ขายที่ดิน เนื้อที่350 ตรว 4แปลง ที่ดินตั้งอยู่...    l9935
# 154                          ขายที่ดินทำเลดี บุรีรัมย์    l9979
#
#     CodeProperty  SellPrice  Costestimate  CostestimateB  MarketPrice  ...  \
# 0            562    7000000       8000000        8000000      7500000  ...
# 1                   3600000       3200000        3000000      3400000  ...
# 2            621    8720000       8600000        8500000      8600000  ...
# 3        6402761   45000000      44200000       43500000     46000000  ...
# 4            237   26400000      25200000       25400000     26000000  ...
# ..           ...        ...           ...            ...          ...  ...
# 150                30000000      29000000       28000000     29500000  ...
# 151                 5600000             0              0            0  ...
# 152                 6983000             0              0            0  ...
# 153                 4900000             0              0            0  ...
# 154          502   16200000      16000000       16000000     15000000  ...
#
#       PPStatus                                            ImageEX Owner  \
# 0    ยังไม่ขาย  https://landvist.xyz/images/img_1589049746930.jpg    27
# 1    ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    30
# 2    ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    27
# 3                https://landvist.xyz/images/mg_1569590149875.jpg    27
# 4    ยังไม่ขาย  https://landvist.xyz/images/NewImg/img_1591201...    27
# ..         ...                                                ...   ...
# 150  ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    63
# 151  ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    79
# 152  ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    79
# 153  ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    79
# 154  ยังไม่ขาย      https://landvist.xyz/images/Defult/Defult.png    59
#
#                  Created    UserType ColorType_n AsseStatus_n UserType_n  \
# 0    1477-05-09 00:07:21   Long-Term           1            4          0
# 1    1476-11-17 08:18:33  Short-Term           4            4          1
# 2    1476-11-18 04:27:40   Long-Term           5            4          0
# 3    1476-09-27 10:45:32   Long-Term           6            4          0
# 4    1476-11-21 16:00:32   Long-Term           2            4          0
# ..                   ...         ...         ...          ...        ...
# 150  1476-11-17 08:15:29   Long-Term           4            4          0
# 151  1477-07-22 01:17:10  Short-Term           5            3          1
# 152  1457-01-01 17:00:00  Short-Term           9            3          1
# 153  1457-01-01 17:00:00  Short-Term           9            3          1
# 154  1476-11-22 06:38:28  Short-Term           4            4          1
#
#     RoadType_n  GroundLevel_n
# 0            1              2
# 1            3              1
# 2            1              1
# 3            6              2
# 4            1              1
# ..         ...            ...
# 150          6              1
# 151          1              2
# 152          1              0
# 153          1              2
# 154          1              2
#
# [155 rows x 57 columns]

# %% [markdown]
# #### Prepare dataset for model training

# %%
df_land_select = df_land_current[['ColorType_n', 'CostestimateB', 'SellPrice', 'MarketPrice',  'RoadType_n', 'AsseStatus_n', 'UserType_n']]
df_land_select
# Out:
#      ColorType_n  CostestimateB  SellPrice  MarketPrice  RoadType_n  \
# 0              1        8000000    7000000      7500000           1
# 1              4        3000000    3600000      3400000           3
# 2              5        8500000    8720000      8600000           1
# 3              6       43500000   45000000     46000000           6
# 4              2       25400000   26400000     26000000           1
# ..           ...            ...        ...          ...         ...
# 150            4       28000000   30000000     29500000           6
# 151            5              0    5600000            0           1
# 152            9              0    6983000            0           1
# 153            9              0    4900000            0           1
# 154            4       16000000   16200000     15000000           1
#
#      AsseStatus_n  UserType_n
# 0               4           0
# 1               4           1
# 2               4           0
# 3               4           0
# 4               4           0
# ..            ...         ...
# 150             4           0
# 151             3           1
# 152             3           1
# 153             3           1
# 154             4           1
#
# [155 rows x 7 columns]

# %% [markdown]
# #### Export Cleaned Dataset

# %%
# model training dataset
df_land_select.to_csv(r'C:\Users\OS\Desktop\Model Improvement Dataset\df_cleaned_land_model_001-09-2020.txt', index=False)
df_land_select.to_csv(r'C:\Users\OS\Desktop\Model Improvement Dataset\df_cleaned_land_model_001-09-2020.csv', index=False)

# entire dataset
df_land_updated.to_csv(r'C:\Users\OS\Desktop\Model Improvement Dataset\df_cleaned_land_001-09-2020.txt', index=False)
